# %% [markdown]
# <a href="https://colab.research.google.com/github/tigerak/tigerak/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 신경망 기초 수학

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %%
def linear_function(x):
    a = 0.5
    b = 2

    return a*x + b

# %%
print(linear_function(5))
# Out:
# 4.5

# %%
x = np.arange(-5, 5, 0.1)
y = linear_function(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def quadratic_function(x):
    a = 1
    b = -1
    c = -2

    return a*x**2 + b*x + c

# %%
print(quadratic_function(2))
# Out:
# 0

# %%
x = np.arange(-5, 5, 0.1)
y = quadratic_function(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def cubic_function(x):
    a = 4
    b = 0
    c = -1
    d = -8

    return a*x**3 + b*x**2 + c*x + d

# %%
print(cubic_function(3))
# Out:
# 97

# %%
x = np.arange(-5, 5, 0.1)
y = cubic_function(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 함수의 최대 최소값

# %%
def my_fun(x):
    a = 1
    b = -3
    c = 10
    return a*x**2 + b*x + c

# %%
x = np.arange(-10, 10, 0.1)
y = my_fun(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(1.5, my_fun(1.5))
plt.text(1.5-1.5, my_fun(1.5)+10, 'min value of f(x)\n({}, {})'.format(1.5, my_fun(1.5)), fontsize=10)
plt.show()

# %%
min_val = min(y)
print(min_val)
# Out:
# 7.75

# %% [markdown]
# 특정 구간 내에서 최소값 구하기

# %%
def get_minimum(x1, x2, f):
    x = np.arange(x1, x2, 0.01)
    y = f(x)

    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

    return min(y)

# %%
print(get_minimum(1, 4, my_fun))
# Out:
# 7.75

# %% [markdown]
# # 지수와 로그

# %% [markdown]
# 지수 함수

# %%
def exponential_function(x):
    a = 4
    return a**x

# %%
print(exponential_function(4))
print(exponential_function(0))
# Out:
# 256
# 1

# %%
x = np.arange(-3, 2, 0.1)
y = exponential_function(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-4, 3)
plt.ylim(-1, 15)
plt.show()

# %%
def exponential_function(x):
    a =4
    return math.pow(a, x)

# %%
print(exponential_function(4))
print(exponential_function(0))
# Out:
# 256.0
# 1.0

# %% [markdown]
# 밑이 e인 지수함수

# %%
print(math.exp(4))

print(np.exp(4))
# Out:
# 54.598150033144236
# 54.598150033144236

# %% [markdown]
# 로그함수

# %%
print(math.log(2, 3))

print(np.log2(4))
print(np.log(4))
# Out:
# 0.6309297535714574
# 2.0
# 1.3862943611198906

# %% [markdown]
# 역함수 관계계

# %%
x = np.arange(-1, 5, 0.01)
y1 = np.exp(x)

x2 = np.arange(0.000001, 5, 0.01)
y2 = np.log(x2)

y3 = x

plt.plot(x, y1, 'r-', x2, y2, 'b-', x, y3, 'k--')

plt.ylim(-2, 6)
plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.show()

# %% [markdown]
# 함수 조작

# %%
x = np.arange(-10, 10, 0.01)
y1 = -np.log(x)
y2 = -np.log(1-x)

plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.grid()
plt.plot(x, y1, 'b-', x, y2, 'r-')
plt.text(0.9, 2.0, 'y=-log(1-x)')
plt.text(0.1, 3, 'y=-log(x)')
plt.xlim(-0.3, 1.4)
plt.ylim(-0.5, 4)
plt.scatter(0.5, -np.log(0.5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # 극한

# %%
from sympy import *
init_printing()

x, y, z = symbols('x y z')
a, b, c, t =symbols('a b c t')

# %%
print('극한값 : ', limit((x**3-1) / (x-1), x, 1))

plot(((x**3-1) / (x-1)), xlim=(-5, 5), ylim=(-1, 10));
# Out:
# 극한값 :  3

# %%
print('극한값 : ', limit((1 + x) / x, x, oo))

plot((1 + x) / x, xlim=(-10, 10), ylim=(-5, 5));
# Out:
# 극한값 :  1

# %%
print('극한값 : ', limit( (sqrt(x+3) - 2) / (x - 1), x, 1 ) )

plot( (sqrt(x+3)-2) / (x-1), xlim=(-5, 12), ylim=(-0.5, 1) )
# Out:
# 극한값 :  1/4

# %% [markdown]
# 삼각함수의 극한

# %%
print('극한값 : ', limit( tan(x), x ,pi/2, '+'))
print('극한값 : ', limit( tan(x), x ,pi/2, '-'))

plot( tan(x), xlim=(-3.14, 3.14), ylim=(-6, 6))
# Out:
# 극한값 :  -oo
# 극한값 :  oo

# %%
print('극한값 : ', limit( sin(x)/x, x, 0))

plot(sin(x)/x, ylim=(-2, 2))
# Out:
# 극한값 :  1

# %%
print('극한값 : ', limit( x*sin(1/x), x, 0))

plot( x*sin(1/x), xlim=(-2, 2), ylim=(-1, 1.5))
# Out:
# 극한값 :  0

# %% [markdown]
# 지수함수, 로그함수의 극한

# %%
print('극한값 : ', limit( (2**x - 2**(-x)) / (2**x + 2**(-x)), x, oo) )

plot((2**x - 2**(-x)) / (2**x + 2**(-x)), xlim=(-10, 10), ylim=(-3, 3));
# Out:
# 극한값 :  1

# %%
print('극한값 : ', limit( log(x+1, 2) - log(x, 2), x, oo))

plot( log(x, 2), log(x+1, 2), xlim=(-4, 6), ylim=(-4, 4))
# Out:
# 극한값 :  0

# %% [markdown]
# 자연로그 e의 밑

# %%
print('1 : ', limit( (1+1/x)**x, x, oo ) )
print('2 : ', limit( (1+2/x)**x, x, oo ) )
print('3 : ', limit( (exp(x)-1) / x, x, 0 ) )
print('4 : ', limit( ln(1+x) / x, x, 0 ) )
# Out:
# 1 :  E
# 2 :  exp(2)
# 3 :  1
# 4 :  1

# %% [markdown]
# # 미분과 기울기
